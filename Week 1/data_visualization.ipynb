# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
titanic = pd.read_csv('titanic.csv')
survival_counts = titanic['Survived'].value_counts()

# %% [markdown]
# ### - Generate a chat of passenger survival rate

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='Survived', data=titanic, palette='pastel')
plt.xticks([0,1],['Not Survived', 'Survived'])
plt.title('Survival Count')
plt.xlabel('Survival')
plt.ylabel('Count')
# Out:
# /var/folders/b9/fqrwtf1d55gdfjqsw56545k00000gn/T/ipykernel_19462/1692248933.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Survived', data=titanic, palette='pastel')
# Text(0, 0.5, 'Count')

# %% [markdown]
# ### - Generate a chat of passenger age distribution

# %%
plt.figure(figsize=(8,5))
sns.histplot(titanic['Age'].dropna(), bins=30, kde=True, color='skyblue')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ### - Iris Species Example

# %%
iris = pd.read_csv('Iris.csv')
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
plt.figure(figsize=(6,5))
sns.scatterplot(data=iris, x='PetalLengthCm', y='PetalWidthCm', hue='Species', palette='Set2')
plt.title('Petal Length vs Width by Species')
plt.xlabel('Petal Length')
plt.ylabel('Petal Width')
# Out:
# Text(0, 0.5, 'Petal Width')

# %% [markdown]
# In this exercise, I have done the following graphs using `matplotlib` and `seaborn`:
#
# - Bar chart of survival rate
# - Histogram of age distribution
# - Scatterplot of features for the Iris dataset
#
# Through these charts, I have initially learned common visualization skills, laying the foundation for subsequent data analysis.
